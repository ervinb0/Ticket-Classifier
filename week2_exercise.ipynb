# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/sample1.csv')
df.head()
# Out:
#                                            issue_url issue_label  \
# 0  https://api.github.com/repos/deepnight/ldtk/is...         bug
# 1  https://api.github.com/repos/sef-global/sef-si...         bug
# 2  https://api.github.com/repos/cherry-script/che...         bug
# 3  https://api.github.com/repos/IgniteUI/igniteui...         bug
# 4  https://api.github.com/repos/OpenSIPS/opensips...         bug
#
#        issue_created_at issue_author_association  \
# 0  2021-03-10T01:39:16Z              CONTRIBUTOR
# 1  2021-01-30T13:51:30Z             COLLABORATOR
# 2  2021-04-07T13:38:24Z              CONTRIBUTOR
# 3  2020-10-16T15:41:48Z              CONTRIBUTOR
# 4  2020-09-21T21:22:05Z                     NONE
#
#                                       repository_url  \
# 0        https://api.github.com/repos/deepnight/ldtk
# 1   https://api.github.com/repos/sef-global/sef-site
# 2  https://api.github.com/repos/cherry-script/che...
# 3  https://api.github.com/repos/IgniteUI/igniteui...
# ...

# %%
df
# Out:
#                                                issue_url issue_label  \
# 0      https://api.github.com/repos/deepnight/ldtk/is...         bug
# 1      https://api.github.com/repos/sef-global/sef-si...         bug
# 2      https://api.github.com/repos/cherry-script/che...         bug
# 3      https://api.github.com/repos/IgniteUI/igniteui...         bug
# 4      https://api.github.com/repos/OpenSIPS/opensips...         bug
# ...                                                  ...         ...
# 72284  https://api.github.com/repos/rancher/k3d/issue...    question
# 72285  https://api.github.com/repos/node-formidable/f...    question
# 72286  https://api.github.com/repos/ebaauw/homebridge...    question
# 72287  https://api.github.com/repos/envoyproxy/envoy/...    question
# 72288  https://api.github.com/repos/jonthornton/Datep...    question
#
#            issue_created_at issue_author_association  \
# 0      2021-03-10T01:39:16Z              CONTRIBUTOR
# ...

# %%
df_1 = df.drop(columns=['issue_url', 'issue_created_at', 'issue_author_association', 'repository_url'])
df_1.head()
# Out:
#   issue_label                                        issue_title  \
# 0         bug  __tileSrcRect is null in Entities.ldtk Sample ...
# 1         bug               Update the blog link in the SEF Site
# 2         bug  🐛 Parser cannot properly distinguish between p...
# 3         bug  "Row added" snackbar is not visible if the gri...
# 4         bug  [CRASH]  _tcp_write_on_socket crashes when flu...
#
#                                           issue_body
# 0  In the Entities example, we there are some `__...
# 1  **Describe the bug**\r\nUpdate the blog link i...
# 2  Consider these two expressions:\r\n```\r\nf (g...
# 3  ## Description  \r\nWhen grid has no height an...
# 4  <!--\r\nThank you for reporting a crash in Ope...

# %%
specific_word = 'why'  # replace with the word you are looking for
filtered_df = df[df['issue_body'].str.contains(specific_word, na=False)]
filtered_df
# Out:
#                                                issue_url issue_label  \
# 46     https://api.github.com/repos/nextauthjs/next-a...         bug
# 82     https://api.github.com/repos/dbeaver/dbeaver/i...         bug
# 89     https://api.github.com/repos/m-triassi/soen390...         bug
# 100    https://api.github.com/repos/kovidgoyal/kitty/...         bug
# 235    https://api.github.com/repos/storybookjs/story...         bug
# ...                                                  ...         ...
# 72197  https://api.github.com/repos/bblanchon/Arduino...    question
# 72201  https://api.github.com/repos/cp2004/OctoPrint-...    question
# 72202  https://api.github.com/repos/torognes/swarm/is...    question
# 72260  https://api.github.com/repos/zowe/api-layer/is...    question
# 72282  https://api.github.com/repos/binguishensu/gith...    question
#
#            issue_created_at issue_author_association  \
# 46     2020-11-16T16:11:14Z                     NONE
# ...

# %%
filtered_questions_df = df[(df['issue_label'] == 'question') & (df['issue_body'].str.contains("who", na=False))]
filtered_questions_df
# Out:
#                                                issue_url issue_label  \
# 66047  https://api.github.com/repos/jerosoler/Drawflo...    question
# 66100  https://api.github.com/repos/man-group/dtale/i...    question
# 66131  https://api.github.com/repos/arrayfire/arrayfi...    question
# 66227  https://api.github.com/repos/myspaghetti/macos...    question
# 66238  https://api.github.com/repos/nVentiveUX/docker...    question
# ...                                                  ...         ...
# 72254  https://api.github.com/repos/horovod/horovod/i...    question
# 72259  https://api.github.com/repos/z3APA3A/3proxy/is...    question
# 72261  https://api.github.com/repos/nextauthjs/next-a...    question
# 72278  https://api.github.com/repos/josdejong/jsonedi...    question
# 72282  https://api.github.com/repos/binguishensu/gith...    question
#
#            issue_created_at issue_author_association  \
# 66047  2021-01-15T15:57:08Z                     NONE
# ...
